# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HarDNet-MSEG
# Out:
# /content/drive/MyDrive/HarDNet-MSEG

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 22.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 94.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 38.2 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %%
# !npm install localtunnel
# Out:
# npm WARN enoent ENOENT: no such file or directory, open '/content/drive/MyDrive/HarDNet-MSEG/package.json'
# npm WARN HarDNet-MSEG No description
# npm WARN HarDNet-MSEG No repository field.
# npm WARN HarDNet-MSEG No README data
# npm WARN HarDNet-MSEG No license field.
#
# npm ERR! code EEXIST
# npm ERR! path /content/drive/MyDrive/HarDNet-MSEG/node_modules/.bin/lt
# npm ERR! Refusing to delete /content/drive/MyDrive/HarDNet-MSEG/node_modules/.bin/lt: is outside /content/drive/MyDrive/HarDNet-MSEG/node_modules/localtunnel and not a link
# npm ERR! File exists: /content/drive/MyDrive/HarDNet-MSEG/node_modules/.bin/lt
# npm ERR! Remove the existing file and try again, or run npm
# npm ERR! with --force to overwrite files recklessly.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2023-07-03T00_43_16_019Z-debug.log

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] \ fetchMetadata: sill resolveWithNewModule yargs@17.1.1 ch
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
# npx: installed 22 in 3.609s
# your url is: https://dark-trams-ask.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8502
#   External URL: http://34.123.245.209:8502
